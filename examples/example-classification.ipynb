# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess data
x_train = np.expand_dims(x_train, -1).astype("float32") / 255
x_test = np.expand_dims(x_test, -1).astype("float32") / 255
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, batch_size=128, epochs=5, validation_split=0.1)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\rini\DATA\#Git-Stash\machine-learning-adventures\examples\example-classification.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rini/DATA/%23Git-Stash/machine-learning-adventures/examples/example-classification.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> model.fit(x_train, y_train, batch_size=128, epochs=5, validation_split=0.1)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py:323, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     321 for step, iterator in epoch_iterator.enumerate_epoch():
#     322     callbacks.on_train_batch_begin(step)
# --> 323     logs = self.train_function(iterator)
#     324     callbacks.on_train_batch_end(
#     325         step, self._pythonify_logs(logs)
#     326     )
#     327     if self.stop_training:
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:889, in Function._call(self, *args, **kwds)
#     886 try:
#     887   # This is the first call of __call__, so we have to initialize.
#     888   initializers = []
# --> 889   self._initialize(args, kwds, add_initializers_to=initializers)
#     890 finally:
#     891   # At this point we know that the initialization is complete (or less
#     892   # interestingly an exception was raised) so we no longer need a lock.
#     893   self._lock.release()
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:339, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     337 if is_autograph_artifact(f):
#     338   logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339   return _call_unconverted(f, args, kwargs, options)
#     341 # If this is a partial, unwrap it and redo all the checks.
#     342 if isinstance(f, functools.partial):
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py:117, in TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator(iterator)
#     115 """Runs a single training step given a Dataset iterator."""
#     116 data = next(iterator)
# --> 117 outputs = self.distribute_strategy.run(
#     118     one_step_on_data, args=(data,)
#     119 )
#     120 outputs = reduce_per_replica(
#     121     outputs,
#     122     self.distribute_strategy,
#     123     reduction=self.distribute_reduction_method,
#     124 )
#     125 return outputs
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/distribute/distribute_lib.py:1681, in StrategyBase.run(***failed resolving arguments***)
#    1676 with self.scope():
#    1677   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1678   # applied when the caller is also in Eager mode.
#    1679   fn = autograph.tf_convert(
#    1680       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1681   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/distribute/distribute_lib.py:3271, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3269   kwargs = {}
#    3270 with self._container_strategy().scope():
# -> 3271   return self._call_for_each_replica(fn, args, kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/distribute/distribute_lib.py:4069, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4067 def _call_for_each_replica(self, fn, args, kwargs):
#    4068   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4069     return fn(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:906, in Function._call(self, *args, **kwds)
#     902     pass  # Fall through to cond-based initialization.
#     903   else:
#     904     # Lifting succeeded, so variables are initialized and we can run the
#     905     # no_variable_creation function.
# --> 906     return tracing_compilation.call_function(
#     907         args, kwds, self._no_variable_creation_config
#     908     )
#     909 else:
#     910   bound_args = self._concrete_variable_creation_fn.function_type.bind(
#     911       *args, **kwds
#     912   )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:132, in call_function(args, kwargs, tracing_options)
#     130 args = args if args else ()
#     131 kwargs = kwargs if kwargs else {}
# --> 132 function = trace_function(
#     133     args=args, kwargs=kwargs, tracing_options=tracing_options
#     134 )
#     136 # Bind it ourselves to skip unnecessary canonicalization of default call.
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/impl/api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py:105, in TensorFlowTrainer.make_train_function.<locals>.one_step_on_data(data)
#     102 @tf.autograph.experimental.do_not_convert
#     103 def one_step_on_data(data):
#     104     """Runs a single training step on a batch of data."""
# --> 105     return self.train_step(data)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py:62, in TensorFlowTrainer.train_step(self, data)
#      58     y_pred = self(x)
#      59 loss = self.compute_loss(
#      60     x=x, y=y, y_pred=y_pred, sample_weight=sample_weight
#      61 )
# ---> 62 self._loss_tracker.update_state(loss)
#      63 if self.optimizer is not None:
#      64     loss = self.optimizer.scale_loss(loss)
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/metrics/reduction_metrics.py:137, in Mean.update_state(self, values, sample_weight)
#     133 def update_state(self, values, sample_weight=None):
#     134     values, sample_weight = reduce_to_samplewise_values(
#     135         values, sample_weight, reduce_fn=ops.mean, dtype=self.dtype
#     136     )
# --> 137     self.total.assign(self.total + ops.sum(values))
#     138     if len(values.shape) >= 1:
#     139         num_samples = ops.shape(values)[0]
#
# File /usr/local/lib/python3.11/dist-packages/keras/src/backend/common/variables.py:240, in KerasVariable.__add__(self, other)
#     238 def __add__(self, other):
#     239     value = self.value
# --> 240     return value.__add__(self._convert_to_tensor(other, dtype=value.dtype))
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/variables.py:1013, in Variable._OverloadOperator.<locals>._run_op(a, *args, **kwargs)
#    1011 def _run_op(a, *args, **kwargs):
#    1012   # pylint: disable=protected-access
# -> 1013   return tensor_oper(a.value(), *args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/resource_variable_ops.py:634, in BaseResourceVariable.value(self)
#     632   return self._cached_value
#     633 with ops.colocate_with(None, ignore_existing=True):
# --> 634   return self._read_variable_op()
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/resource_variable_ops.py:818, in BaseResourceVariable._read_variable_op(self, no_copy)
#     816       result = read_and_set_handle(no_copy)
#     817 else:
# --> 818   result = read_and_set_handle(no_copy)
#     820 if not context.executing_eagerly():
#     821   # Note that if a control flow context is active the input of the read op
#     822   # might not actually be the handle. This line bypasses it.
#     823   record.record_operation(
#     824       "ReadVariableOp", [result], [self.handle],
#     825       backward_function=lambda x: [x],
#     826       forward_function=lambda x: [x])
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/resource_variable_ops.py:808, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     806 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     807   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 808 result = gen_resource_variable_ops.read_variable_op(
#     809     self.handle, self._dtype)
#     810 _maybe_set_handle_data(self._dtype, self.handle, result)
#     811 return result
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/gen_resource_variable_ops.py:548, in read_variable_op(resource, dtype, name)
#     546 # Add nodes to the TensorFlow graph.
#     547 dtype = _execute.make_type(dtype, "dtype")
# --> 548 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#     549       "ReadVariableOp", resource=resource, dtype=dtype, name=name)
#     550 _result = _outputs[:]
#     551 if _execute.must_record_gradient():
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/op_def_library.py:778, in _apply_op_helper(op_type_name, name, **keywords)
#     776 with g.as_default(), ops.name_scope(name) as scope:
#     777   if fallback:
# --> 778     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     779                            keywords, default_type_attr_map, attrs, inputs,
#     780                            input_types)
#     781     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     782                            default_type_attr_map, attrs)
#     783     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/op_def_library.py:551, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     545       values = ops.convert_to_tensor(
#     546           values,
#     547           name=input_arg.name,
#     548           as_ref=input_arg.is_ref,
#     549           preferred_dtype=default_dtype)
#     550   else:
# --> 551     values = ops.convert_to_tensor(
#     552         values,
#     553         name=input_arg.name,
#     554         dtype=dtype,
#     555         as_ref=input_arg.is_ref,
#     556         preferred_dtype=default_dtype)
#     557 except TypeError as err:
#     558   if dtype is None:
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py:699, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     697 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     698 preferred_dtype = preferred_dtype or dtype_hint
# --> 699 return tensor_conversion_registry.convert(
#     700     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     701 )
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py:209, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207 overload = getattr(value, "__tf_tensor__", None)
#     208 if overload is not None:
# --> 209   return overload(dtype, name)  #  pylint: disable=not-callable
#     211 for base_type, conversion_func in get(type(value)):
#     212   # If dtype is None but preferred_dtype is not None, we try to
#     213   # cast to preferred_dtype first.
#     214   ret = None
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py:593, in _EagerTensorBase.__tf_tensor__(self, dtype, name)
#     587   if not graph.building_function:
#     588     raise RuntimeError(
#     589         _add_error_prefix(
#     590             "Attempting to capture an EagerTensor without "
#     591             "building a function.",
#     592             name=name))
# --> 593   return graph.capture(self, name=name)
#     594 return super().__tf_tensor__(dtype, name)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/func_graph.py:675, in FuncGraph.capture(self, tensor, name, shape)
#     674 def capture(self, tensor, name=None, shape=None):
# --> 675   return self._function_captures.capture_by_value(self, tensor, name)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/core/function/capture/capture_container.py:141, in FunctionCaptures.capture_by_value(self, graph, tensor, name)
#     138     return graph_const
#     140   # Large EagerTensors and resources are captured with Placeholder ops
# --> 141   return self._create_placeholder_helper(graph, tensor, name)
#     143 if tensor.graph is not graph:
#     144   graph._validate_in_scope(tensor)  # pylint: disable=protected-access
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/core/function/capture/capture_container.py:285, in FunctionCaptures._create_placeholder_helper(self, graph, tensor, name)
#     279   composite_device_name = None
#     280 placeholder_ctx = trace_type.InternalPlaceholderContext(
#     281     graph,
#     282     with_none_control_dependencies=True,
#     283     composite_device_name=composite_device_name,
#     284 )
# --> 285 placeholder = spec.placeholder_value(placeholder_ctx)
#     286 self.add_or_replace(
#     287     key=id(tensor), external=tensor, internal=placeholder, is_by_ref=False
#     288 )
#     289 graph.inputs.append(placeholder)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/tensor.py:1020, in TensorSpec.placeholder_value(self, placeholder_context)
#    1016 if placeholder_context.with_none_control_dependencies:
#    1017   # Note: setting ops.control_dependencies(None) ensures we always put
#    1018   # capturing placeholders outside of any control flow context.
#    1019   with context_graph.control_dependencies(None):
# -> 1020     placeholder = self._graph_placeholder(context_graph, name=name)
#    1021 else:
#    1022   placeholder = self._graph_placeholder(context_graph, name=name)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/tensor.py:1060, in TensorSpec._graph_placeholder(self, graph, name)
#    1058 attrs = {"dtype": dtype_value, "shape": shape}
#    1059 try:
# -> 1060   op = graph._create_op_internal(  # pylint: disable=protected-access
#    1061       "Placeholder", [], [dtype], input_types=[],
#    1062       attrs=attrs, name=name)
#    1063 except ValueError as e:
#    1064   # TODO(b/262413656) Sometimes parameter names are not valid op names, in
#    1065   # which case an unnamed placeholder is created instead. Update this logic
#    1066   # to sanitize the name instead of falling back on unnamed placeholders.
#    1067   logging.warning(e)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py:2660, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2657 node_def = _NodeDef(op_type, name, attrs)
#    2659 input_ops = set(t.op for t in inputs)
# -> 2660 control_inputs = self._control_dependencies_for_inputs(input_ops)
#    2661 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2662 # Session.run call cannot occur between creating and mutating the op.
#    2663 with self._mutation_lock():
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py:3801, in Graph._control_dependencies_for_inputs(self, input_ops)
#    3796       break
#    3797   if not dominated:
#    3798     # Don't add a control input if we already have a data dependency on i.
#    3799     # NOTE(mrry): We do not currently track transitive data dependencies,
#    3800     #   so we may add redundant control inputs.
# -> 3801     ret.extend(c for c in controller.control_inputs if c not in input_ops)
#    3802 return ret
#
# File /usr/local/lib/python3.11/dist-packages/tensorflow/python/framework/ops.py:3801, in <genexpr>(.0)
#    3796       break
#    3797   if not dominated:
#    3798     # Don't add a control input if we already have a data dependency on i.
#    3799     # NOTE(mrry): We do not currently track transitive data dependencies,
#    3800     #   so we may add redundant control inputs.
# -> 3801     ret.extend(c for c in controller.control_inputs if c not in input_ops)
#    3802 return ret
#
# KeyboardInterrupt:

# %%
import numpy as np

# Select a random test image
test_image = x_test[np.random.choice(x_test.shape[0])]

# Direct Prediction
prediction = model.predict(np.expand_dims(test_image, axis=0))
predicted_class = np.argmax(prediction, axis=1)
print(f"Direct Prediction - Class: {predicted_class}")

# Top K Prediction
k = 3
top_k_predictions = np.argsort(prediction, axis=1)[0][-k:][::-1]
print(f"Top {k} Prediction - Classes: {top_k_predictions}")

# Softmax Probabilities
softmax_probabilities = np.squeeze(prediction)
print(f"Softmax Probabilities: {softmax_probabilities}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Direct Prediction - Class: [2]
# Top 3 Prediction - Classes: [2 3 1]
# Softmax Probabilities: [2.82448926e-08 3.04889749e-04 9.99328494e-01 3.34145734e-04
#  6.36691200e-10 2.43326592e-11 2.51819870e-07 7.50832623e-06
#  2.47832104e-05 1.14044496e-10]
